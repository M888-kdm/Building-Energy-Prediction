# %%
# %reload_ext autoreload
# %autoreload 2

import numpy as np
import pandas as pd
import ppscore as pps
import os
import sys
import seaborn as sns

from loguru import logger
from matplotlib import pyplot as plt
from pathlib import Path
from scipy import stats

sys.path.append(str(Path.cwd().parent))

from settings.params import *
from src.utils import configure_logger

pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 100)
configure_logger()

# %%
data = pd.read_csv(RAW_DATA)
TARGET_NAME = MODEL_PARAMS['TARGET_NAME']

# %% [markdown]
# # Data Preparation

# %%
logger.info("Preparing Data")
# Out:
# 2024-08-08 14:45:48.640 | INFO     | __main__:<module>:1 - Preparing Data

# %% [markdown]
# ## Data Cleaning

# %%
logger.info("Handling missing, incoherent and duplicate values")
# Out:
# 2024-08-08 14:45:48.688 | INFO     | __main__:<module>:1 - Handling missing, incoherent and duplicate values

# %%
# Checking if there is duplicate data
duplicate = data[data.duplicated()]
logger.info(f"Number of duplicate values: {len(duplicate)}")
# Out:
# 2024-08-08 14:45:48.733 | INFO     | __main__:<module>:3 - Number of duplicate values: 0

# %%
# Counts of null values for each column
data.isna().sum()
# Out:
# OSEBuildingID                         0
# DataYear                              0
# BuildingType                          0
# PrimaryPropertyType                   0
# PropertyName                          0
# TaxParcelIdentificationNumber         2
# CouncilDistrictCode                   0
# Neighborhood                          0
# YearBuilt                             0
# NumberofBuildings                     8
# NumberofFloors                        8
# PropertyGFATotal                      0
# PropertyGFAParking                    0
# PropertyGFABuilding(s)                0
# ListOfAllPropertyUseTypes           136
# LargestPropertyUseType              156
# LargestPropertyUseTypeGFA           156
# SecondLargestPropertyUseType       3478
# SecondLargestPropertyUseTypeGFA    3478
# ThirdLargestPropertyUseType        5560
# ThirdLargestPropertyUseTypeGFA     5560
# YearsENERGYSTARCertified           6487
# ENERGYSTARScore                    1623
# SiteEUI(kBtu/sf)                     17
# SiteEUIWN(kBtu/sf)                   16
# SourceEUI(kBtu/sf)                   19
# SourceEUIWN(kBtu/sf)                 19
# SiteEnergyUse(kBtu)                  15
# SiteEnergyUseWN(kBtu)                16
# SteamUse(kBtu)                       19
# Electricity(kWh)                     19
# Electricity(kBtu)                    19
# NaturalGas(therms)                   19
# NaturalGas(kBtu)                     19
# DefaultData                        3335
# ComplianceStatus                      0
# Outlier                            6600
# Latitude                              0
# Longitude                             0
# State                                 0
# ZipCode                              16
# City                                  0
# Address                               0
# TotalGHGEmissions                    19
# GHGEmissionsIntensity                19
# dtype: int64

# %% [markdown]
# We can populate some of the the missing information in some columns with simple strategies

# %%
# If there are no second and third property usage types, replace NaN with "No Use"
data[['ThirdLargestPropertyUseType', 'SecondLargestPropertyUseType']] = data[['ThirdLargestPropertyUseType', 'SecondLargestPropertyUseType']].fillna('No Use')

# If there are no second and third property usage types, replace GFA with 0
data[['ThirdLargestPropertyUseTypeGFA', 'SecondLargestPropertyUseTypeGFA']] = data[['ThirdLargestPropertyUseTypeGFA', 'SecondLargestPropertyUseTypeGFA']].fillna(0, )

# If LargestPropertyUseType is missing, replace with No Information
data['LargestPropertyUseType'] = data['LargestPropertyUseType'].fillna('No information')

# %%
# If the row is neither a high or low outlier, replace missing value with 'normal'
data['Outlier'].replace(np.nan,'normal', inplace=True)

# %% [markdown]
# We are now going to drop the rows of the dataset marked as being non-compliant. When a record is indicated as such, it means that the information collected about it is erronous. We cannot feed that data to our model.

# %%
indexes_to_drop = data[data['ComplianceStatus'] == 'Non-Compliant'].index
data.drop(indexes_to_drop, inplace=True, axis=0)

# %% [markdown]
# Next we can drop the rows for which we the compliance status indicate missing data. For those rows, the energy consumption is zero on the dataset.

# %%
indexes_to_drop = data[data['ComplianceStatus'] == 'Missing Data'].index
data.drop(indexes_to_drop, inplace=True, axis=0)

# %% [markdown]
# The are also other rows for which energy consumption is 0 or Nan. Some records indicate 0 electricity consumption or have a missing value for that column. They are going to be dropped from the dataset.

# %%
# Remaining records indicating no energy usage
data[data[TARGET_NAME] == 0]
# Out:
#       OSEBuildingID  DataYear       BuildingType PrimaryPropertyType  \
# 44               58      2015     NonResidential        Retail Store
# 572             765      2015     NonResidential        Large Office
# 4701          21616      2016  SPS-District K-12         K-12 School
#
#                   PropertyName TaxParcelIdentificationNumber  \
# 44       CENTURY SQUARE RETAIL                    1975700365
# 572              SEATTLE TOWER                    1975200005
# 4701  Olympic Hills Elementary                    2126049041
#
#       CouncilDistrictCode Neighborhood  YearBuilt  NumberofBuildings  \
# 44                      7     DOWNTOWN       1920                1.0
# 572                     7     DOWNTOWN       1929                1.0
# 4701                    5        NORTH       1954                1.0
#
#       NumberofFloors  PropertyGFATotal  PropertyGFAParking  \
# 44               2.0             57428                   0
# 572             27.0            216571               13320
# 4701             1.0             42292                   0
#
#       PropertyGFABuilding(s)                        ListOfAllPropertyUseTypes  \
# 44                     57428  Non-Refrigerated Warehouse, Other, Retail Store
# 572                   203251      Office, Other - Technology/Science, Parking
# 4701                   42292                                      K-12 School
#
#      LargestPropertyUseType  LargestPropertyUseTypeGFA  \
# 44             Retail Store                    34617.0
# 572                  Office                   182604.0
# 4701            K-12 School                    43188.0
#
#      SecondLargestPropertyUseType  SecondLargestPropertyUseTypeGFA  \
# 44     Non-Refrigerated Warehouse                          13028.0
# 572                       Parking                          13320.0
# 4701                       No Use                              0.0
#
#      ThirdLargestPropertyUseType  ThirdLargestPropertyUseTypeGFA  \
# 44                         Other                          9783.0
# 572   Other - Technology/Science                          6246.0
# 4701                      No Use                             0.0
#
#      YearsENERGYSTARCertified  ENERGYSTARScore  SiteEUI(kBtu/sf)  \
# 44                        NaN              NaN               0.0
# 572    2014, 2013, 2012, 2008              NaN               0.0
# 4701                      NaN            100.0               0.0
#
#       SiteEUIWN(kBtu/sf)  SourceEUI(kBtu/sf)  SourceEUIWN(kBtu/sf)  \
# 44                   0.0                 0.0                   0.0
# 572                  0.0                 0.0                   0.0
# 4701                 0.0                 0.0                   0.0
#
#       SiteEnergyUse(kBtu)  SiteEnergyUseWN(kBtu)  SteamUse(kBtu)  \
# 44                    0.0                    0.0             0.0
# 572                   0.0                    0.0             0.0
# 4701                  0.0                    0.0             0.0
#
#       Electricity(kWh)  Electricity(kBtu)  NaturalGas(therms)  \
# 44                 0.0                0.0                 0.0
# 572                0.0                0.0                 0.0
# 4701               0.0                0.0                 0.0
#
#       NaturalGas(kBtu) DefaultData              ComplianceStatus Outlier  \
# 44                 0.0         NaN                     Compliant  normal
# 572                0.0         NaN                     Compliant  normal
# 4701               0.0        True  Error - Correct Default Data  normal
#
#        Latitude   Longitude State  ZipCode     City               Address  \
# 44    47.610764 -122.337677    WA  98101.0  Seattle          1525 4TH AVE
# 572   47.607655 -122.335512    WA  98101.0  Seattle          1218 3RD AVE
# 4701  47.723690 -122.306760    WA  98125.0  Seattle  13018 20th Ave. N.E.
#
#       TotalGHGEmissions  GHGEmissionsIntensity
# 44                  0.0                    0.0
# 572                 0.0                    0.0
# 4701                0.0                    0.0

# %%
# Records indicating no electricity usage
data[data['Electricity(kWh)'] == 0]
# Out:
#       OSEBuildingID  DataYear          BuildingType  \
# 44               58      2015        NonResidential
# 572             765      2015        NonResidential
# 3766          23854      2016        NonResidential
# 3853            700      2016        NonResidential
# 4663          21524      2016  Multifamily LR (1-4)
# 4701          21616      2016     SPS-District K-12
#
#               PrimaryPropertyType               PropertyName  \
# 44                   Retail Store      CENTURY SQUARE RETAIL
# 572                  Large Office              SEATTLE TOWER
# 3766                   Restaurant                    Pier 57
# 3853  Supermarket / Grocery Store  IUC- Whole Foods Interbay
# 4663         Low-Rise Multifamily     Minor Tower Apartments
# 4701                  K-12 School   Olympic Hills Elementary
#
#      TaxParcelIdentificationNumber  CouncilDistrictCode  \
# 44                      1975700365                    7
# 572                     1975200005                    7
# 3766                    7666202435                    7
# 3853                    7666201460                    7
# 4663                    2025049091                    4
# 4701                    2126049041                    5
#
#                Neighborhood  YearBuilt  NumberofBuildings  NumberofFloors  \
# 44                 DOWNTOWN       1920                1.0             2.0
# 572                DOWNTOWN       1929                1.0            27.0
# 3766               DOWNTOWN       1900                1.0             1.0
# 3853  MAGNOLIA / QUEEN ANNE       2008                1.0             1.0
# 4663             LAKE UNION       1974                1.0             4.0
# 4701                  NORTH       1954                1.0             1.0
#
#       PropertyGFATotal  PropertyGFAParking  PropertyGFABuilding(s)  \
# 44               57428                   0                   57428
# 572             216571               13320                  203251
# 3766             43728                   0                   43728
# 3853             57176                   0                   57176
# 4663             37361                4735                   32626
# 4701             42292                   0                   42292
#
#                               ListOfAllPropertyUseTypes  \
# 44      Non-Refrigerated Warehouse, Other, Retail Store
# 572         Office, Other - Technology/Science, Parking
# 3766                                         Restaurant
# 3853  Personal Services (Health/Beauty, Dry Cleaning...
# 4663                                Multifamily Housing
# 4701                                        K-12 School
#
#          LargestPropertyUseType  LargestPropertyUseTypeGFA  \
# 44                 Retail Store                    34617.0
# 572                      Office                   182604.0
# 3766                 Restaurant                    43728.0
# 3853  Supermarket/Grocery Store                    39500.0
# 4663        Multifamily Housing                    27732.0
# 4701                K-12 School                    43188.0
#
#      SecondLargestPropertyUseType  SecondLargestPropertyUseTypeGFA  \
# 44     Non-Refrigerated Warehouse                          13028.0
# 572                       Parking                          13320.0
# 3766                       No Use                              0.0
# 3853                 Retail Store                          15000.0
# 4663                       No Use                              0.0
# 4701                       No Use                              0.0
#
#                             ThirdLargestPropertyUseType  \
# 44                                                Other
# 572                          Other - Technology/Science
# 3766                                             No Use
# 3853  Personal Services (Health/Beauty, Dry Cleaning...
# 4663                                             No Use
# 4701                                             No Use
#
#       ThirdLargestPropertyUseTypeGFA YearsENERGYSTARCertified  \
# 44                            9783.0                      NaN
# 572                           6246.0   2014, 2013, 2012, 2008
# 3766                             0.0                      NaN
# 3853                          5500.0                      NaN
# 4663                             0.0                      NaN
# 4701                             0.0                      NaN
#
#       ENERGYSTARScore  SiteEUI(kBtu/sf)  SiteEUIWN(kBtu/sf)  \
# 44                NaN          0.000000            0.000000
# 572               NaN          0.000000            0.000000
# 3766              NaN        263.200012          271.100006
# 3853             31.0        208.800003          214.100006
# 4663             61.0         31.700001           33.200001
# 4701            100.0          0.000000            0.000000
#
#       SourceEUI(kBtu/sf)  SourceEUIWN(kBtu/sf)  SiteEnergyUse(kBtu)  \
# 44              0.000000              0.000000                  0.0
# 572             0.000000              0.000000                  0.0
# 3766          276.299988            284.600006           11508035.0
# 3853            0.000000              0.000000           12525174.0
# 4663            0.000000              0.000000             880115.5
# 4701            0.000000              0.000000                  0.0
#
#       SiteEnergyUseWN(kBtu)  SteamUse(kBtu)  Electricity(kWh)  \
# 44             0.000000e+00             0.0               0.0
# 572            0.000000e+00             0.0               0.0
# 3766           1.185445e+07             0.0               0.0
# 3853           1.284386e+07             0.0               0.0
# 4663           9.197677e+05             0.0               0.0
# 4701           0.000000e+00             0.0               0.0
#
#       Electricity(kBtu)  NaturalGas(therms)  NaturalGas(kBtu) DefaultData  \
# 44                  0.0              0.0000               0.0         NaN
# 572                 0.0              0.0000               0.0         NaN
# 3766                0.0         115080.3516        11508035.0       False
# 3853                0.0              0.0000               0.0       False
# 4663                0.0              0.0000               0.0       False
# 4701                0.0              0.0000               0.0        True
#
#                   ComplianceStatus Outlier   Latitude   Longitude State  \
# 44                       Compliant  normal  47.610764 -122.337677    WA
# 572                      Compliant  normal  47.607655 -122.335512    WA
# 3766                     Compliant  normal  47.606130 -122.341150    WA
# 3853                     Compliant  normal  47.637180 -122.377340    WA
# 4663                     Compliant  normal  47.642720 -122.328660    WA
# 4701  Error - Correct Default Data  normal  47.723690 -122.306760    WA
#
#       ZipCode     City                Address  TotalGHGEmissions  \
# 44    98101.0  Seattle           1525 4TH AVE               0.00
# 572   98101.0  Seattle           1218 3RD AVE               0.00
# 3766  98101.0  Seattle       1301 Alaskan Way             611.19
# 3853  98119.0  Seattle  2001 15th Avenue West               0.00
# 4663  98102.0  Seattle       2525 Minor Ave E               0.00
# 4701  98125.0  Seattle   13018 20th Ave. N.E.               0.00
#
#       GHGEmissionsIntensity
# 44                     0.00
# 572                    0.00
# 3766                  13.98
# 3853                   0.00
# 4663                   0.00
# 4701                   0.00

# %%
# Records having a missing value for electricity usage
data[data['Electricity(kWh)'].isna()]
# Out:
#       OSEBuildingID  DataYear          BuildingType   PrimaryPropertyType  \
# 62               87      2015     SPS-District K-12           K-12 School
# 719           19694      2015     SPS-District K-12           K-12 School
# 1358          21570      2015     SPS-District K-12           K-12 School
# 1360          21578      2015     SPS-District K-12           K-12 School
# 2108          24408      2015     SPS-District K-12           K-12 School
# 2381          25361      2015     SPS-District K-12           K-12 School
# 2406          25451      2015        NonResidential          Restaurant\n
# 5108          23355      2016  Multifamily LR (1-4)  Low-Rise Multifamily
# 5661          25431      2016  Multifamily LR (1-4)  Low-Rise Multifamily
# 5820          25763      2016  Multifamily LR (1-4)  Low-Rise Multifamily
# 6688          50082      2016  Multifamily LR (1-4)  Low-Rise Multifamily
#
#                                         PropertyName  \
# 62    ARBOR HEIGHTS ELEMENTARY SCHOOL (SPS-DISTRICT)
# 719                              MANN (SPS-DISTRICT)
# 1358             PINEHURST ELEMENTARY (SPS-DISTRICT)
# 1360                   GENESEE SCHOOL (SPS-DISTRICT)
# 2108                   WILSON-PACIFIC (SPS-DISTRICT)
# 2381               DECATUR ELEMENTARY (SPS-DISTRICT)
# 2406                             YALE STREET LANDING
# 5108                                     GRAHAM VIEW
# 5661                                   PONDERAY APTS
# 5820                                    Villa Andora
# 6688                                  STREAM FIFTEEN
#
#      TaxParcelIdentificationNumber  CouncilDistrictCode Neighborhood  \
# 62                      2518400005                    1    SOUTHWEST
# 719                      519000290                    3      CENTRAL
# 1358                    2044500390                    5        NORTH
# 1360                    2095200005                    1    SOUTHWEST
# 2108                    3126049064                    5    NORTHWEST
# 2381                    6392002430                    4    NORTHEAST
# 2406                    4088803010                    3   LAKE UNION
# 5108                    7625703280                    1    SOUTHWEST
# 5661                    5226300030                    4    NORTHEAST
# 5820                    9272201340                    1    SOUTHWEST
# 6688                    3303700030                    3         EAST
#
#       YearBuilt  NumberofBuildings  NumberofFloors  PropertyGFATotal  \
# 62         1948                1.0             2.0             53352
# 719        1925                1.0             2.0             37327
# 1358       1950                1.0             1.0             34005
# 1360       1949                1.0             1.0             41221
# 2108       1953                1.0             1.0            110830
# 2381       1961                1.0             1.0             43578
# 2406       1978                1.0             2.0             26519
# 5108       1992                NaN             4.0             29357
# 5661       1963                NaN             4.0             28472
# 5820       1969                NaN             3.0             30420
# 6688       2015                1.0             4.0             36685
#
#       PropertyGFAParking  PropertyGFABuilding(s) ListOfAllPropertyUseTypes  \
# 62                     0                   53352               K-12 School
# 719                    0                   37327               K-12 School
# 1358                   0                   34005               K-12 School
# 1360                   0                   41221               K-12 School
# 2108                   0                  110830               K-12 School
# 2381                   0                   43578               K-12 School
# 2406                   0                   26519        Office, Restaurant
# 5108                   0                   29357                       NaN
# 5661                   0                   28472                       NaN
# 5820                   0                   30420                       NaN
# 6688                8254                   28431                       NaN
#
#      LargestPropertyUseType  LargestPropertyUseTypeGFA  \
# 62              K-12 School                    53352.0
# 719             K-12 School                    41191.0
# 1358            K-12 School                    34005.0
# 1360            K-12 School                    41221.0
# 2108            K-12 School                   110830.0
# 2381            K-12 School                    45370.0
# 2406             Restaurant                    13592.0
# 5108         No information                        NaN
# 5661         No information                        NaN
# 5820         No information                        NaN
# 6688         No information                        NaN
#
#      SecondLargestPropertyUseType  SecondLargestPropertyUseTypeGFA  \
# 62                         No Use                              0.0
# 719                        No Use                              0.0
# 1358                       No Use                              0.0
# 1360                       No Use                              0.0
# 2108                       No Use                              0.0
# 2381                       No Use                              0.0
# 2406                       Office                          12927.0
# 5108                       No Use                              0.0
# 5661                       No Use                              0.0
# 5820                       No Use                              0.0
# 6688                       No Use                              0.0
#
#      ThirdLargestPropertyUseType  ThirdLargestPropertyUseTypeGFA  \
# 62                        No Use                             0.0
# 719                       No Use                             0.0
# 1358                      No Use                             0.0
# 1360                      No Use                             0.0
# 2108                      No Use                             0.0
# 2381                      No Use                             0.0
# 2406                      No Use                             0.0
# 5108                      No Use                             0.0
# 5661                      No Use                             0.0
# 5820                      No Use                             0.0
# 6688                      No Use                             0.0
#
#      YearsENERGYSTARCertified  ENERGYSTARScore  SiteEUI(kBtu/sf)  \
# 62                        NaN              NaN               NaN
# 719                       NaN              NaN               NaN
# 1358                      NaN              NaN               NaN
# 1360                      NaN              NaN               NaN
# 2108                      NaN              NaN               NaN
# 2381                      NaN              NaN               NaN
# 2406                      NaN              NaN               NaN
# 5108                      NaN              NaN         19.200001
# 5661                      NaN              NaN         27.100000
# 5820                      NaN              NaN         34.500000
# 6688                      NaN              NaN         30.100000
#
#       SiteEUIWN(kBtu/sf)  SourceEUI(kBtu/sf)  SourceEUIWN(kBtu/sf)  \
# 62                   NaN                 NaN                   NaN
# 719                  NaN                 NaN                   NaN
# 1358                 NaN                 NaN                   NaN
# 1360                 NaN                 NaN                   NaN
# 2108                 NaN                 NaN                   NaN
# 2381                 NaN                 NaN                   NaN
# 2406                 NaN                 NaN                   NaN
# 5108           20.200001                 NaN                   NaN
# 5661           28.000000                 NaN                   NaN
# 5820           37.000000                 NaN                   NaN
# 6688           31.500000                 NaN                   NaN
#
#       SiteEnergyUse(kBtu)  SiteEnergyUseWN(kBtu)  SteamUse(kBtu)  \
# 62                    NaN                    NaN             NaN
# 719                   NaN                    NaN             NaN
# 1358                  NaN                    NaN             NaN
# 1360                  NaN                    NaN             NaN
# 2108                  NaN                    NaN             NaN
# 2381                  NaN                    NaN             NaN
# 2406                  NaN                    NaN             NaN
# 5108         5.636832e+05           5.937986e+05             NaN
# 5661         7.702755e+05           7.975070e+05             NaN
# 5820         1.049639e+06           1.126782e+06             NaN
# 6688         8.202201e+05           8.576127e+05             NaN
#
#       Electricity(kWh)  Electricity(kBtu)  NaturalGas(therms)  \
# 62                 NaN                NaN                 NaN
# 719                NaN                NaN                 NaN
# 1358               NaN                NaN                 NaN
# 1360               NaN                NaN                 NaN
# 2108               NaN                NaN                 NaN
# 2381               NaN                NaN                 NaN
# 2406               NaN                NaN                 NaN
# 5108               NaN                NaN                 NaN
# 5661               NaN                NaN                 NaN
# 5820               NaN                NaN                 NaN
# 6688               NaN                NaN                 NaN
#
#       NaturalGas(kBtu) DefaultData ComplianceStatus      Outlier   Latitude  \
# 62                 NaN         NaN        Compliant  Low Outlier  47.509354
# 719                NaN         NaN        Compliant       normal  47.608185
# 1358               NaN         NaN        Compliant       normal  47.713343
# 1360               NaN         NaN        Compliant  Low Outlier  47.565464
# 2108               NaN         NaN        Compliant       normal  47.695489
# 2381               NaN         NaN        Compliant       normal  47.685590
# 2406               NaN         NaN        Compliant       normal  47.629180
# 5108               NaN       False        Compliant       normal  47.547310
# 5661               NaN       False        Compliant       normal  47.670250
# 5820               NaN       False        Compliant       normal  47.589680
# 6688               NaN       False        Compliant       normal  47.624410
#
#        Longitude State  ZipCode     City                 Address  \
# 62   -122.378222    WA  98146.0  Seattle        3701 SW 104TH ST
# 719  -122.300521    WA  98122.0  Seattle        2410 E CHERRY ST
# 1358 -122.314590    WA  98125.0  Seattle       11530 12TH AVE NE
# 1360 -122.396881    WA  98116.0  Seattle      5012 SW GENESEE ST
# 2108 -122.340188    WA  98103.0  Seattle          1330 N 90TH ST
# 2381 -122.282590    WA  98115.0  Seattle        7711 43RD AVE NE
# 2406 -122.331695    WA  98109.0  Seattle     1001 FAIRVIEW AVE N
# 5108 -122.386560    WA  98136.0  Seattle  6040 CALIFORNIA AVE SW
# 5661 -122.312320    WA  98105.0  Seattle        5625 15TH AVE NE
# 5820 -122.385870    WA  98116.0  Seattle  1520 CALIFORNIA AVE SW
# 6688 -122.313000    WA  98112.0  Seattle          605 15TH AVE E
#
#       TotalGHGEmissions  GHGEmissionsIntensity
# 62                  NaN                    NaN
# 719                 NaN                    NaN
# 1358                NaN                    NaN
# 1360                NaN                    NaN
# 2108                NaN                    NaN
# 2381                NaN                    NaN
# 2406                NaN                    NaN
# 5108                NaN                    NaN
# 5661                NaN                    NaN
# 5820                NaN                    NaN
# 6688                NaN                    NaN

# %%
index_to_drop = data[(data[TARGET_NAME] == 0) | (data[TARGET_NAME].isna()) | (data['Electricity(kBtu)'] == 0) | (data['Electricity(kBtu)']).isna()].index
print(index_to_drop)
print(f'there are {len(index_to_drop)} samples with 0 energy consumption reported -> Drop')
data.drop(index_to_drop, inplace=True, axis=0)
# Out:
# Int64Index([  44,   62,  572,  719, 1358, 1360, 2108, 2381, 2406, 3766, 3853,
#             4663, 4701, 5108, 5661, 5820, 6688],
#            dtype='int64')
# there are 17 samples with 0 energy consumption reported -> Drop

# %%
data.isna().sum()
# Out:
# OSEBuildingID                         0
# DataYear                              0
# BuildingType                          0
# PrimaryPropertyType                   0
# PropertyName                          0
# TaxParcelIdentificationNumber         2
# CouncilDistrictCode                   0
# Neighborhood                          0
# YearBuilt                             0
# NumberofBuildings                     0
# NumberofFloors                        8
# PropertyGFATotal                      0
# PropertyGFAParking                    0
# PropertyGFABuilding(s)                0
# ListOfAllPropertyUseTypes           124
# LargestPropertyUseType                0
# LargestPropertyUseTypeGFA           144
# SecondLargestPropertyUseType          0
# SecondLargestPropertyUseTypeGFA       0
# ThirdLargestPropertyUseType           0
# ThirdLargestPropertyUseTypeGFA        0
# YearsENERGYSTARCertified           6417
# ENERGYSTARScore                    1575
# SiteEUI(kBtu/sf)                      0
# SiteEUIWN(kBtu/sf)                    1
# SourceEUI(kBtu/sf)                    0
# SourceEUIWN(kBtu/sf)                  0
# SiteEnergyUse(kBtu)                   0
# SiteEnergyUseWN(kBtu)                 1
# SteamUse(kBtu)                        0
# Electricity(kWh)                      0
# Electricity(kBtu)                     0
# NaturalGas(therms)                    0
# NaturalGas(kBtu)                      0
# DefaultData                        3323
# ComplianceStatus                      0
# Outlier                               0
# Latitude                              0
# Longitude                             0
# State                                 0
# ZipCode                              16
# City                                  0
# Address                               0
# TotalGHGEmissions                     0
# GHGEmissionsIntensity                 0
# dtype: int64

# %% [markdown]
# In this step, we are going to correct the apparent incoherences in the columns NumberOfFloors and NumberOfBuildings. As shown below, some records have values of 0 for them. We'll also replace the missing values for them.

# %%
# NumberOfFloors Value counts
data["NumberofFloors"].value_counts()
# Out:
# 4.0     1375
# 3.0     1375
# 1.0      902
# 2.0      869
# 6.0      603
# 5.0      583
# 7.0      279
# 8.0      123
# 11.0      64
# 10.0      63
# 13.0      41
# 12.0      39
# 9.0       36
# 14.0      25
# 0.0       21
# 17.0      18
# 15.0      15
# 16.0      14
# 18.0      14
# 24.0      13
# 23.0      13
# 19.0      12
# 26.0      12
# 42.0      12
# 33.0      12
# 21.0      10
# 25.0      10
# 20.0       9
# 27.0       9
# 22.0       8
# 29.0       6
# 41.0       5
# 37.0       4
# 36.0       4
# 34.0       4
# 31.0       4
# 28.0       4
# 32.0       2
# 39.0       2
# 76.0       2
# 38.0       2
# 99.0       2
# 55.0       2
# 56.0       2
# 30.0       2
# 46.0       2
# 63.0       2
# 49.0       2
# 47.0       2
# 40.0       2
# Name: NumberofFloors, dtype: int64

# %%
# NumberOfBuildings Value Counts
data["NumberofBuildings"].value_counts()
# Out:
# 1.0      6434
# 0.0        92
# 2.0        41
# 3.0        25
# 4.0        13
# 5.0         9
# 6.0         8
# 7.0         4
# 10.0        3
# 8.0         3
# 16.0        2
# 14.0        2
# 9.0         2
# 11.0        2
# 39.0        1
# 27.0        1
# 23.0        1
# 111.0       1
# Name: NumberofBuildings, dtype: int64

# %%
# Replace missing values and zeros in NumberOfFloors with the most representative value
data['NumberofFloors'].replace(np.nan, 3, inplace=True)
data['NumberofFloors'].replace(0, 3, inplace=True)

# %%
# Replace missing values and zeros in NumberOfBuildings with the most representative value
data['NumberofBuildings'].replace(np.nan, 1, inplace=True)
data['NumberofBuildings'].replace(0, 1, inplace=True)

# %% [markdown]
# Since the building types present in the data are mostly for housing and offices, we can replace the missing values in LargestPropertyUseTypeGFA with the corresponding values of PropertyGFABuilding(s)

# %%
data[data['LargestPropertyUseTypeGFA'].isna()]
# Out:
#       OSEBuildingID  DataYear          BuildingType  \
# 10               15      2015        NonResidential
# 14               19      2015        NonResidential
# 19               25      2015        NonResidential
# 35               46      2015        NonResidential
# 52               67      2015        NonResidential
# ...             ...       ...                   ...
# 5754          25568      2016        NonResidential
# 5799          25711      2016        NonResidential
# 5885          26026      2016  Multifamily LR (1-4)
# 6226          27343      2016  Multifamily LR (1-4)
# 6380          27966      2016  Multifamily LR (1-4)
#
#               PrimaryPropertyType                             PropertyName  \
# 10                          Hotel                             HOTEL MONACO
# 14                          Hotel                       HOTEL VINTAGE PARK
# 19                          Hotel  DOUBLE TREE ARCTIC CLUB HOTEL - SEATTLE
# 35            Distribution Center        SEATTLE WAREHOUSE OFFICE BUILDING
# 52                          Hotel           QUALITY INN & SUITES - SEATTLE
# ...                           ...                                      ...
# 5754  Small- and Mid-Sized Office                      Talon Northlake LLC
# 5799                   Restaurant         BUSH GARDEN - RESTURANT & LOUNGE
# 5885         Low-Rise Multifamily              Westwood Plaza Condominiums
# 6226         Low-Rise Multifamily                            Ravenna Woods
# 6380         Low-Rise Multifamily                           Pinehurst Lane
#
#      TaxParcelIdentificationNumber  CouncilDistrictCode      Neighborhood  \
# 10                       942000145                    7          DOWNTOWN
# 14                       942000265                    7          DOWNTOWN
# 19                       942000610                    7          DOWNTOWN
# 35                       323049024                    2  GREATER DUWAMISH
# 52                      1991200730                    7        LAKE UNION
# ...                            ...                  ...               ...
# 5754                    4088804565                    4        LAKE UNION
# 5799                    5247802410                    2          DOWNTOWN
# 5885                    9325000000                    1          DELRIDGE
# 6226                    7181200000                    5         NORTHEAST
# 6380                    6798800000                    5             NORTH
#
#       YearBuilt  NumberofBuildings  NumberofFloors  PropertyGFATotal  \
# 10         1969                1.0            11.0            153163
# 14         1922                1.0            11.0             67390
# 19         1916                1.0            10.0            104352
# 35         1961                7.0             2.0            714095
# 52         1959                1.0             5.0            113173
# ...         ...                ...             ...               ...
# 5754       2008                1.0             4.0             48350
# 5799       1913                1.0             3.0             28800
# 5885       1981                1.0             3.0             35122
# 6226       1981                1.0             3.0             42448
# 6380       1997                1.0             4.0             23175
#
#       PropertyGFAParking  PropertyGFABuilding(s)    ListOfAllPropertyUseTypes  \
# 10                 19279                  133884                          NaN
# 14                     0                   67390                          NaN
# 19                     0                  104352                          NaN
# 35                     0                  714095                          NaN
# 52                 42546                   70627                          NaN
# ...                  ...                     ...                          ...
# 5754                   0                   48350                       Office
# 5799                   0                   28800                   Restaurant
# 5885                   0                   35122          Multifamily Housing
# 6226                   0                   42448          Multifamily Housing
# 6380                   0                   23175  Multifamily Housing, Office
#
#      LargestPropertyUseType  LargestPropertyUseTypeGFA  \
# 10           No information                        NaN
# 14           No information                        NaN
# 19           No information                        NaN
# 35           No information                        NaN
# 52           No information                        NaN
# ...                     ...                        ...
# 5754         No information                        NaN
# 5799         No information                        NaN
# 5885         No information                        NaN
# 6226         No information                        NaN
# 6380         No information                        NaN
#
#      SecondLargestPropertyUseType  SecondLargestPropertyUseTypeGFA  \
# 10                         No Use                              0.0
# 14                         No Use                              0.0
# 19                         No Use                              0.0
# 35                         No Use                              0.0
# 52                         No Use                              0.0
# ...                           ...                              ...
# 5754                       No Use                              0.0
# 5799                       No Use                              0.0
# 5885                       No Use                              0.0
# 6226                       No Use                              0.0
# 6380                       No Use                              0.0
#
#      ThirdLargestPropertyUseType  ThirdLargestPropertyUseTypeGFA  \
# 10                        No Use                             0.0
# 14                        No Use                             0.0
# 19                        No Use                             0.0
# 35                        No Use                             0.0
# 52                        No Use                             0.0
# ...                          ...                             ...
# 5754                      No Use                             0.0
# 5799                      No Use                             0.0
# 5885                      No Use                             0.0
# 6226                      No Use                             0.0
# 6380                      No Use                             0.0
#
#      YearsENERGYSTARCertified  ENERGYSTARScore  SiteEUI(kBtu/sf)  \
# 10                        NaN             48.0        101.100000
# 14                        NaN             14.0        166.100000
# 19                        NaN             83.0         75.200000
# 35                        NaN              1.0         66.900000
# 52                        NaN             86.0         70.600000
# ...                       ...              ...               ...
# 5754                      NaN             45.0         72.199997
# 5799                      NaN              NaN         31.200001
# 5885                      NaN             43.0         29.200001
# 6226                      NaN             66.0         29.400000
# 6380                      NaN              NaN         30.900000
#
#       SiteEUIWN(kBtu/sf)  SourceEUI(kBtu/sf)  SourceEUIWN(kBtu/sf)  \
# 10            107.200000          200.800000            205.200000
# 14            175.700000          317.400000            326.000000
# 19             74.900000          119.500000            118.600000
# 35             64.700000          210.000000            203.300000
# 52             73.100000          166.600000            174.300000
# ...                  ...                 ...                   ...
# 5754           74.699997          226.600006            234.600006
# 5799           32.500000           62.000000             62.799999
# 5885           31.799999           91.599998             99.800003
# 6226           31.400000           92.300003             98.699997
# 6380           33.000000           74.800003             78.000000
#
#       SiteEnergyUse(kBtu)  SiteEnergyUseWN(kBtu)  SteamUse(kBtu)  \
# 10           1.471985e+07           1.561593e+07       3623542.0
# 14           1.071145e+07           1.132923e+07       4403788.0
# 19           7.845112e+06           7.816594e+06       3205497.0
# 35           4.784389e+07           4.631352e+07             0.0
# 52           4.988241e+06           5.160438e+06             0.0
# ...                   ...                    ...             ...
# 5754         3.168131e+06           3.280956e+06             0.0
# 5799         8.999242e+05           9.358332e+05             0.0
# 5885         9.365844e+05           1.020896e+06             0.0
# 6226         1.247918e+06           1.333831e+06             0.0
# 6380         7.152526e+05           7.643831e+05             0.0
#
#       Electricity(kWh)  Electricity(kBtu)  NaturalGas(therms)  \
# 10        1.857347e+06          6337531.0        47590.000000
# 14        1.198487e+06          4089407.0        22184.000000
# 19        5.247920e+05          1790665.0        28490.000000
# 35        1.402224e+07         47845869.0            0.000000
# 52        9.159880e+05          3125480.0        18629.000000
# ...                ...                ...                 ...
# 5754      9.285260e+05          3168131.0            0.000000
# 5799      1.180853e+05           402907.0         4970.169922
# 5885      2.744971e+05           936584.0            0.000000
# 6226      3.657438e+05          1247918.0            0.000000
# 6380      1.376804e+05           469766.0         2454.870117
#
#       NaturalGas(kBtu) DefaultData ComplianceStatus Outlier   Latitude  \
# 10           4759044.0         NaN        Compliant  normal  47.607121
# 14           2218425.0         NaN        Compliant  normal  47.607616
# 19           2849024.0         NaN        Compliant  normal  47.603979
# 35                 0.0         NaN        Compliant  normal  47.510603
# 52           1862890.0         NaN        Compliant  normal  47.620373
# ...                ...         ...              ...     ...        ...
# 5754               0.0       False        Compliant  normal  47.647470
# 5799          497017.0       False        Compliant  normal  47.596970
# 5885               0.0       False        Compliant  normal  47.524510
# 6226               0.0       False        Compliant  normal  47.693270
# 6380          245487.0       False        Compliant  normal  47.713130
#
#        Longitude State  ZipCode     City               Address  \
# 10   -122.334319    WA  98101.0  Seattle          1101 4TH AVE
# 14   -122.332329    WA  98101.0  Seattle          1100 5TH AVE
# 19   -122.332058    WA  98104.0  Seattle           700 3RD AVE
# 35   -122.290276    WA  98118.0  Seattle     3301 S NORFOLK ST
# 52   -122.344146    WA  98109.0  Seattle           618 JOHN ST
# ...          ...   ...      ...      ...                   ...
# 5754 -122.340860    WA  98103.0  Seattle  1341 N Northlake Way
# 5799 -122.324740    WA  98104.0  Seattle   614 S MAYNARD AVE S
# 5885 -122.364240    WA  98106.0  Seattle    2421 SW Trenton St
# 6226 -122.303470    WA  98115.0  Seattle       2300 NE 89TH ST
# 6380 -122.312140    WA  98125.0  Seattle     11532 15th Ave NE
#
#       TotalGHGEmissions  GHGEmissionsIntensity
# 10               576.63                   3.59
# 14               486.25                   6.95
# 19               411.22                   3.87
# 35               333.54                   0.18
# 52               120.73                   0.95
# ...                 ...                    ...
# 5754              22.09                   0.46
# 5799              29.21                   1.01
# 5885               6.53                   0.19
# 6226               8.70                   0.20
# 6380              16.31                   0.70
#
# [144 rows x 45 columns]

# %%
# Replace missing values in LargestPropertyUseTypeGFA with the corresponding PropertyGFABuilding(s)
for index in range(len(data)):
    if np.isnan(data.iloc[index]['LargestPropertyUseTypeGFA']):
        data['LargestPropertyUseTypeGFA'].iloc[index] = data['PropertyGFABuilding(s)'].iloc[index]
# Out:
# /var/folders/cr/49y6g29x0wsct947q6zx6d3c0000gn/T/ipykernel_91225/1267038597.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['LargestPropertyUseTypeGFA'].iloc[index] = data['PropertyGFABuilding(s)'].iloc[index]

# %%
data.isna().sum()
# Out:
# OSEBuildingID                         0
# DataYear                              0
# BuildingType                          0
# PrimaryPropertyType                   0
# PropertyName                          0
# TaxParcelIdentificationNumber         2
# CouncilDistrictCode                   0
# Neighborhood                          0
# YearBuilt                             0
# NumberofBuildings                     0
# NumberofFloors                        0
# PropertyGFATotal                      0
# PropertyGFAParking                    0
# PropertyGFABuilding(s)                0
# ListOfAllPropertyUseTypes           124
# LargestPropertyUseType                0
# LargestPropertyUseTypeGFA             0
# SecondLargestPropertyUseType          0
# SecondLargestPropertyUseTypeGFA       0
# ThirdLargestPropertyUseType           0
# ThirdLargestPropertyUseTypeGFA        0
# YearsENERGYSTARCertified           6417
# ENERGYSTARScore                    1575
# SiteEUI(kBtu/sf)                      0
# SiteEUIWN(kBtu/sf)                    1
# SourceEUI(kBtu/sf)                    0
# SourceEUIWN(kBtu/sf)                  0
# SiteEnergyUse(kBtu)                   0
# SiteEnergyUseWN(kBtu)                 1
# SteamUse(kBtu)                        0
# Electricity(kWh)                      0
# Electricity(kBtu)                     0
# NaturalGas(therms)                    0
# NaturalGas(kBtu)                      0
# DefaultData                        3323
# ComplianceStatus                      0
# Outlier                               0
# Latitude                              0
# Longitude                             0
# State                                 0
# ZipCode                              16
# City                                  0
# Address                               0
# TotalGHGEmissions                     0
# GHGEmissionsIntensity                 0
# dtype: int64

# %% [markdown]
# ### Removing Outliers

# %%
logger.info("Handling outliers")
# Out:
# 2024-08-08 14:45:50.183 | INFO     | __main__:<module>:1 - Handling outliers

# %% [markdown]
# In order to remove outliers, we are going to use the z-score. The information contained in the Outlier column will help us detect the false outliers from the true ones. Only records whose z_score for energy usage is more than 3 and not indicated as true outliers will be dropped.

# %%
target = data[TARGET_NAME]
z_scores = np.abs((target - target.mean()) / target.std())

# %%
data = data.drop(data[(z_scores >= 3) & (data['Outlier'] == 'normal')].index, axis=0)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6591 entries, 0 to 6715
# Data columns (total 45 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   OSEBuildingID                    6591 non-null   int64
#  1   DataYear                         6591 non-null   int64
#  2   BuildingType                     6591 non-null   object
#  3   PrimaryPropertyType              6591 non-null   object
#  4   PropertyName                     6591 non-null   object
#  5   TaxParcelIdentificationNumber    6589 non-null   object
#  6   CouncilDistrictCode              6591 non-null   int64
#  7   Neighborhood                     6591 non-null   object
#  8   YearBuilt                        6591 non-null   int64
#  9   NumberofBuildings                6591 non-null   float64
#  10  NumberofFloors                   6591 non-null   float64
#  11  PropertyGFATotal                 6591 non-null   int64
#  12  PropertyGFAParking               6591 non-null   int64
#  13  PropertyGFABuilding(s)           6591 non-null   int64
#  14  ListOfAllPropertyUseTypes        6468 non-null   object
#  15  LargestPropertyUseType           6591 non-null   object
#  16  LargestPropertyUseTypeGFA        6591 non-null   float64
#  17  SecondLargestPropertyUseType     6591 non-null   object
#  18  SecondLargestPropertyUseTypeGFA  6591 non-null   float64
#  19  ThirdLargestPropertyUseType      6591 non-null   object
#  20  ThirdLargestPropertyUseTypeGFA   6591 non-null   float64
#  21  YearsENERGYSTARCertified         222 non-null    object
#  22  ENERGYSTARScore                  5036 non-null   float64
#  23  SiteEUI(kBtu/sf)                 6591 non-null   float64
#  24  SiteEUIWN(kBtu/sf)               6590 non-null   float64
#  25  SourceEUI(kBtu/sf)               6591 non-null   float64
#  26  SourceEUIWN(kBtu/sf)             6591 non-null   float64
#  27  SiteEnergyUse(kBtu)              6591 non-null   float64
#  28  SiteEnergyUseWN(kBtu)            6590 non-null   float64
#  29  SteamUse(kBtu)                   6591 non-null   float64
#  30  Electricity(kWh)                 6591 non-null   float64
#  31  Electricity(kBtu)                6591 non-null   float64
#  32  NaturalGas(therms)               6591 non-null   float64
#  33  NaturalGas(kBtu)                 6591 non-null   float64
#  34  DefaultData                      3294 non-null   object
#  35  ComplianceStatus                 6591 non-null   object
#  36  Outlier                          6591 non-null   object
#  37  Latitude                         6591 non-null   float64
#  38  Longitude                        6591 non-null   float64
#  39  State                            6591 non-null   object
#  40  ZipCode                          6575 non-null   float64
#  41  City                             6591 non-null   object
#  42  Address                          6591 non-null   object
#  43  TotalGHGEmissions                6591 non-null   float64
#  44  GHGEmissionsIntensity            6591 non-null   float64
# dtypes: float64(22), int64(7), object(16)
# memory usage: 2.3+ MB

# %% [markdown]
# ## Feature Engineering

# %%
logger.info("Feature Engineering !")
# Out:
# 2024-08-08 14:45:50.418 | INFO     | __main__:<module>:1 - Feature Engineering !

# %% [markdown]
# We are going to create new features based on the original ones.
#
# - Instead of working with YearBuilt, it will be more interesting to work with building's ages
# - We cannot use the different types of source energy consumption (Electricity, Gas and Steam) since they are linked to the target, but we can use the ratio of each type of energy.
# - In the same way, instead of using absolute values for PropertyGFAParking, PropertyGFABuilding(s), LargestPropertyUseTypeGFA, second and third, we can work with relative values.

# %%
# Changing YearBuilt column to Age Column with Age = 2016 - YearBuilt
data["Age"] = 2016 - data["YearBuilt"]

# Replace PropertyGFAParking, PropertyGFABuilding, LargestPropertyUseTypeGFA with values relative to PropertyGFATotal
columns = ["PropertyGFAParking", "PropertyGFABuilding(s)", "LargestPropertyUseTypeGFA", "SecondLargestPropertyUseTypeGFA", "ThirdLargestPropertyUseTypeGFA"]
for column in columns:
    ratio_column = column + "Ratio"
    data[ratio_column] = data[column]/data["PropertyGFATotal"]
    

# Create columns for energy type proportion and replace absolute energy value with intensity (kBtu/sf)
columns = ["SteamUse(kBtu)", "Electricity(kBtu)", "NaturalGas(kBtu)"]
for column in columns:
    # Calculating for each type of energy its ratio
    ratio_column = column.replace("(kBtu)", "Ratio")
    data[ratio_column] = data[column]/data["SiteEnergyUse(kBtu)"]

# %% [markdown]
# ## Remove irrelevant and redundant Data

# %% [markdown]
# We are going to remove all the columns that we judged to be unhelpful for the model and redundant data. We will also remove the columns from which came the ones we created in the last step.

# %%
columns = ["DataYear", "City", "State", "DefaultData", "OSEBuildingID", "PrimaryPropertyType", "YearsENERGYSTARCertified", 
            "Address", "CouncilDistrictCode", "PropertyName", "ComplianceStatus", "TaxParcelIdentificationNumber",
            "ZipCode", "SiteEUI(kBtu/sf)", "SiteEUIWN(kBtu/sf)", "SourceEUI(kBtu/sf)", "SourceEUIWN(kBtu/sf)", 
            "SiteEnergyUseWN(kBtu)", "NaturalGas(therms)", "Electricity(kWh)", "TotalGHGEmissions", "ListOfAllPropertyUseTypes",
            "SteamUse(kBtu)", "Electricity(kBtu)", "NaturalGas(kBtu)", "LargestPropertyUseTypeGFA", "SecondLargestPropertyUseTypeGFA", "ThirdLargestPropertyUseTypeGFA",
            "GHGEmissionsIntensity", "PropertyGFAParking", "PropertyGFABuilding(s)", "YearBuilt", "Outlier"]

data = data.drop(columns, axis=1)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6591 entries, 0 to 6715
# Data columns (total 21 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   BuildingType                          6591 non-null   object
#  1   Neighborhood                          6591 non-null   object
#  2   NumberofBuildings                     6591 non-null   float64
#  3   NumberofFloors                        6591 non-null   float64
#  4   PropertyGFATotal                      6591 non-null   int64
#  5   LargestPropertyUseType                6591 non-null   object
#  6   SecondLargestPropertyUseType          6591 non-null   object
#  7   ThirdLargestPropertyUseType           6591 non-null   object
#  8   ENERGYSTARScore                       5036 non-null   float64
#  9   SiteEnergyUse(kBtu)                   6591 non-null   float64
#  10  Latitude                              6591 non-null   float64
#  11  Longitude                             6591 non-null   float64
#  12  Age                                   6591 non-null   int64
#  13  PropertyGFAParkingRatio               6591 non-null   float64
#  14  PropertyGFABuilding(s)Ratio           6591 non-null   float64
#  15  LargestPropertyUseTypeGFARatio        6591 non-null   float64
#  16  SecondLargestPropertyUseTypeGFARatio  6591 non-null   float64
#  17  ThirdLargestPropertyUseTypeGFARatio   6591 non-null   float64
#  18  SteamUseRatio                         6591 non-null   float64
#  19  ElectricityRatio                      6591 non-null   float64
#  20  NaturalGasRatio                       6591 non-null   float64
# dtypes: float64(14), int64(2), object(5)
# memory usage: 1.1+ MB

# %% [markdown]
# ## Feature Selection

# %% [markdown]
# We need to have SiteEnergyUse in log scale in order to have a normal distribution.

# %%
df = data.copy()
df["SiteEnergyUse(kBtu)"] = np.log(df["SiteEnergyUse(kBtu)"])

# %%
pps_predictors = pps.predictors(df=df, y="SiteEnergyUse(kBtu)", random_seed=MODEL_PARAMS["SEED"])
logger.info(f"""Predictive Power Scores: {pps_predictors}""")
pps_predictors
# Out:
# 2024-08-08 14:45:51.185 | INFO     | __main__:<module>:2 - Predictive Power Scores:                                        x                    y   ppscore  \
# 0                       PropertyGFATotal  SiteEnergyUse(kBtu)  0.540764
# 1         LargestPropertyUseTypeGFARatio  SiteEnergyUse(kBtu)  0.202763
# 2                         NumberofFloors  SiteEnergyUse(kBtu)  0.152165
# 3   SecondLargestPropertyUseTypeGFARatio  SiteEnergyUse(kBtu)  0.135812
# 4                 LargestPropertyUseType  SiteEnergyUse(kBtu)  0.121240
# 5                           BuildingType  SiteEnergyUse(kBtu)  0.117382
# 6    ThirdLargestPropertyUseTypeGFARatio  SiteEnergyUse(kBtu)  0.076140
# 7                           Neighborhood  SiteEnergyUse(kBtu)  0.045736
# 8            PropertyGFABuilding(s)Ratio  SiteEnergyUse(kBtu)  0.037828
# 9                PropertyGFAParkingRatio  SiteEnergyUse(kBtu)  0.037828
# 10           ThirdLargestPropertyUseType  SiteEnergyUse(kBtu)  0.035401
# 11          SecondLargestPropertyUseType  SiteEnergyUse(kBtu)  0.025993
# 12                                   Age  SiteEnergyUse(kBtu)  0.022099
# 13                         SteamUseRatio  SiteEnergyUse(kBtu)  0.016197
# 14                       ENERGYSTARScore  SiteEnergyUse(kBtu)  0.002663
# 15                     NumberofBuildings  SiteEnergyUse(kBtu)  0.000000
# 16                              Latitude  SiteEnergyUse(kBtu)  0.000000
# 17                             Longitude  SiteEnergyUse(kBtu)  0.000000
# 18                      ElectricityRatio  SiteEnergyUse(kBtu)  0.000000
# 19                       NaturalGasRatio  SiteEnergyUse(kBtu)  0.000000
#
#           case  is_valid_score               metric  baseline_score  \
# 0   regression            True  mean absolute error        0.859087
# 1   regression            True  mean absolute error        0.859087
# 2   regression            True  mean absolute error        0.859087
# 3   regression            True  mean absolute error        0.859087
# 4   regression            True  mean absolute error        0.859087
# 5   regression            True  mean absolute error        0.859087
# 6   regression            True  mean absolute error        0.859087
# 7   regression            True  mean absolute error        0.859087
# 8   regression            True  mean absolute error        0.859087
# 9   regression            True  mean absolute error        0.859087
# 10  regression            True  mean absolute error        0.859087
# 11  regression            True  mean absolute error        0.859087
# 12  regression            True  mean absolute error        0.859087
# 13  regression            True  mean absolute error        0.859087
# 14  regression            True  mean absolute error        0.831152
# 15  regression            True  mean absolute error        0.859087
# 16  regression            True  mean absolute error        0.859087
# 17  regression            True  mean absolute error        0.859087
# 18  regression            True  mean absolute error        0.859087
# 19  regression            True  mean absolute error        0.859087
#
#     model_score                    model
# 0      0.394523  DecisionTreeRegressor()
# 1      0.684896  DecisionTreeRegressor()
# 2      0.728364  DecisionTreeRegressor()
# 3      0.742413  DecisionTreeRegressor()
# 4      0.754932  DecisionTreeRegressor()
# 5      0.758246  DecisionTreeRegressor()
# 6      0.793677  DecisionTreeRegressor()
# 7      0.819796  DecisionTreeRegressor()
# 8      0.826590  DecisionTreeRegressor()
# 9      0.826590  DecisionTreeRegressor()
# 10     0.828675  DecisionTreeRegressor()
# 11     0.836757  DecisionTreeRegressor()
# 12     0.840102  DecisionTreeRegressor()
# 13     0.845173  DecisionTreeRegressor()
# 14     0.828939  DecisionTreeRegressor()
# 15     0.864275  DecisionTreeRegressor()
# 16     0.954883  DecisionTreeRegressor()
# 17     1.017014  DecisionTreeRegressor()
# 18     1.006892  DecisionTreeRegressor()
# 19     1.000299  DecisionTreeRegressor()
#                                        x                    y   ppscore  \
# 0                       PropertyGFATotal  SiteEnergyUse(kBtu)  0.540764
# 1         LargestPropertyUseTypeGFARatio  SiteEnergyUse(kBtu)  0.202763
# 2                         NumberofFloors  SiteEnergyUse(kBtu)  0.152165
# 3   SecondLargestPropertyUseTypeGFARatio  SiteEnergyUse(kBtu)  0.135812
# 4                 LargestPropertyUseType  SiteEnergyUse(kBtu)  0.121240
# 5                           BuildingType  SiteEnergyUse(kBtu)  0.117382
# 6    ThirdLargestPropertyUseTypeGFARatio  SiteEnergyUse(kBtu)  0.076140
# 7                           Neighborhood  SiteEnergyUse(kBtu)  0.045736
# 8            PropertyGFABuilding(s)Ratio  SiteEnergyUse(kBtu)  0.037828
# 9                PropertyGFAParkingRatio  SiteEnergyUse(kBtu)  0.037828
# 10           ThirdLargestPropertyUseType  SiteEnergyUse(kBtu)  0.035401
# 11          SecondLargestPropertyUseType  SiteEnergyUse(kBtu)  0.025993
# 12                                   Age  SiteEnergyUse(kBtu)  0.022099
# 13                         SteamUseRatio  SiteEnergyUse(kBtu)  0.016197
# 14                       ENERGYSTARScore  SiteEnergyUse(kBtu)  0.002663
# 15                     NumberofBuildings  SiteEnergyUse(kBtu)  0.000000
# 16                              Latitude  SiteEnergyUse(kBtu)  0.000000
# 17                             Longitude  SiteEnergyUse(kBtu)  0.000000
# 18                      ElectricityRatio  SiteEnergyUse(kBtu)  0.000000
# 19                       NaturalGasRatio  SiteEnergyUse(kBtu)  0.000000
#
#           case  is_valid_score               metric  baseline_score  \
# 0   regression            True  mean absolute error        0.859087
# 1   regression            True  mean absolute error        0.859087
# 2   regression            True  mean absolute error        0.859087
# 3   regression            True  mean absolute error        0.859087
# 4   regression            True  mean absolute error        0.859087
# 5   regression            True  mean absolute error        0.859087
# 6   regression            True  mean absolute error        0.859087
# 7   regression            True  mean absolute error        0.859087
# 8   regression            True  mean absolute error        0.859087
# 9   regression            True  mean absolute error        0.859087
# 10  regression            True  mean absolute error        0.859087
# 11  regression            True  mean absolute error        0.859087
# 12  regression            True  mean absolute error        0.859087
# 13  regression            True  mean absolute error        0.859087
# 14  regression            True  mean absolute error        0.831152
# 15  regression            True  mean absolute error        0.859087
# 16  regression            True  mean absolute error        0.859087
# 17  regression            True  mean absolute error        0.859087
# 18  regression            True  mean absolute error        0.859087
# 19  regression            True  mean absolute error        0.859087
#
#     model_score                    model
# 0      0.394523  DecisionTreeRegressor()
# 1      0.684896  DecisionTreeRegressor()
# 2      0.728364  DecisionTreeRegressor()
# 3      0.742413  DecisionTreeRegressor()
# 4      0.754932  DecisionTreeRegressor()
# 5      0.758246  DecisionTreeRegressor()
# 6      0.793677  DecisionTreeRegressor()
# 7      0.819796  DecisionTreeRegressor()
# 8      0.826590  DecisionTreeRegressor()
# 9      0.826590  DecisionTreeRegressor()
# 10     0.828675  DecisionTreeRegressor()
# 11     0.836757  DecisionTreeRegressor()
# 12     0.840102  DecisionTreeRegressor()
# 13     0.845173  DecisionTreeRegressor()
# 14     0.828939  DecisionTreeRegressor()
# 15     0.864275  DecisionTreeRegressor()
# 16     0.954883  DecisionTreeRegressor()
# 17     1.017014  DecisionTreeRegressor()
# 18     1.006892  DecisionTreeRegressor()
# 19     1.000299  DecisionTreeRegressor()

# %% [markdown]
# One of the objectives of this study is also to assess the relevance of the EnergyStarScore in predicting energy usage. And as we can see in the table of predictive power scores (pps), this is not a column with a strong predictive power for energy usage.

# %%
# Check if there are invalid pps scores computed
pps_predictors.is_valid_score.value_counts()
# Out:
# True    20
# Name: is_valid_score, dtype: int64

# %%
# Get features whose pps > MIN_PPS
FEATURE_NAMES = pps_predictors.loc[pps_predictors.ppscore >= MODEL_PARAMS["MIN_PPS"], "x"].values
set(FEATURE_NAMES)
# Out:
# {'BuildingType',
#  'LargestPropertyUseType',
#  'LargestPropertyUseTypeGFARatio',
#  'NumberofFloors',
#  'PropertyGFATotal',
#  'SecondLargestPropertyUseTypeGFARatio',
#  'ThirdLargestPropertyUseTypeGFARatio'}

# %%
logger.info(f"""Selected Features: {FEATURE_NAMES}""")
data.info()
# Out:
# 2024-08-08 14:45:51.482 | INFO     | __main__:<module>:1 - Selected Features: ['PropertyGFATotal' 'LargestPropertyUseTypeGFARatio' 'NumberofFloors'
#  'SecondLargestPropertyUseTypeGFARatio' 'LargestPropertyUseType'
#  'BuildingType' 'ThirdLargestPropertyUseTypeGFARatio']
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6591 entries, 0 to 6715
# Data columns (total 21 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   BuildingType                          6591 non-null   object
#  1   Neighborhood                          6591 non-null   object
#  2   NumberofBuildings                     6591 non-null   float64
#  3   NumberofFloors                        6591 non-null   float64
#  4   PropertyGFATotal                      6591 non-null   int64
#  5   LargestPropertyUseType                6591 non-null   object
#  6   SecondLargestPropertyUseType          6591 non-null   object
#  7   ThirdLargestPropertyUseType           6591 non-null   object
#  8   ENERGYSTARScore                       5036 non-null   float64
#  9   SiteEnergyUse(kBtu)                   6591 non-null   float64
#  10  Latitude                              6591 non-null   float64
#  11  Longitude                             6591 non-null   float64
#  12  Age                                   6591 non-null   int64
#  13  PropertyGFAParkingRatio               6591 non-null   float64
#  14  PropertyGFABuilding(s)Ratio           6591 non-null   float64
#  15  LargestPropertyUseTypeGFARatio        6591 non-null   float64
#  16  SecondLargestPropertyUseTypeGFARatio  6591 non-null   float64
#  17  ThirdLargestPropertyUseTypeGFARatio   6591 non-null   float64
#  18  SteamUseRatio                         6591 non-null   float64
#  19  ElectricityRatio                      6591 non-null   float64
#  20  NaturalGasRatio                       6591 non-null   float64
# dtypes: float64(14), int64(2), object(5)
# memory usage: 1.1+ MB

# %%
data.loc[:, [*FEATURE_NAMES, TARGET_NAME]].describe()
# Out:
#        PropertyGFATotal  LargestPropertyUseTypeGFARatio  NumberofFloors  \
# count      6.591000e+03                     6591.000000     6591.000000
# mean       8.591091e+04                        0.879910        4.631315
# std        1.264349e+05                        0.244408        5.144706
# min        1.128500e+04                        0.147469        1.000000
# 25%        2.837400e+04                        0.748829        2.000000
# 50%        4.372800e+04                        0.994203        4.000000
# 75%        8.809600e+04                        1.000000        5.000000
# max        1.605578e+06                        6.426849       99.000000
#
#        SecondLargestPropertyUseTypeGFARatio  \
# count                           6591.000000
# mean                               0.106246
# std                                0.153134
# min                                0.000000
# 25%                                0.000000
# 50%                                0.000000
# 75%                                0.199986
# max                                1.452054
#
#        ThirdLargestPropertyUseTypeGFARatio  SiteEnergyUse(kBtu)
# count                          6591.000000         6.591000e+03
# mean                              0.015083         4.154195e+06
# std                               0.047225         7.007725e+06
# min                               0.000000         1.144100e+04
# 25%                               0.000000         9.250385e+05
# 50%                               0.000000         1.784233e+06
# 75%                               0.000000         4.036059e+06
# max                               0.489796         5.975744e+07

# %%
data.loc[:, [*FEATURE_NAMES, TARGET_NAME]].to_csv(CLEANED_DATA, index=False)
